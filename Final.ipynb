# %%
# Step 3: Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Step 4: Load dataset
df = pd.read_csv('tips.csv')

# Step 5: Explore dataset
print(df.head())
print(df.info())
print(df.describe())



# Step 7: Compute descriptive statistics
tip_stats = df['tip'].describe()
bill_stats = df['total_bill'].describe()

print("Tip statistics:\n", tip_stats)
print("\nTotal bill statistics:\n", bill_stats)

# Step 8: Visualize distributions
sns.set_style('whitegrid')

plt.figure(figsize=(10,6))
sns.histplot(data=df, x='tip', bins=20, kde=True)
plt.title("Distribution of Tips")
plt.show()

plt.figure(figsize=(10,6))
sns.histplot(data=df, x='total_bill', bins=20, kde=True)
plt.title("Distribution of Total Bill")
plt.show()

plt.figure(figsize=(10,6))
sns.kdeplot(data=df, x='tip', hue='sex', fill=True, alpha=0.5)
plt.title("KDE Plot of Tips by Sex")
plt.show()

plt.figure(figsize=(10,6))
sns.kdeplot(data=df, x='total_bill', hue='sex', fill=True, alpha=0.5)
plt.title("KDE Plot of Total Bill by Sex")
plt.show()

plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='tip')
plt.title("Box Plot of Tips")
plt.show()

plt.figure(figsize=(10,6))
sns.boxplot(data=df, x='total_bill')
plt.title("Box Plot of Total Bill")
plt.show()

# Step 9: Analyze relationship
plt.figure(figsize=(10,6))
sns.scatterplot(data=df, x='total_bill', y='tip', hue='sex')
plt.title("Scatter Plot of Total Bill vs. Tip")
plt.show()


sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB
# None
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# ...
